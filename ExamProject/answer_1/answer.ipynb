# %% [markdown]
# ## 1 Equality Constrained Convex QP
#
# Consider the equality constrained convex QP
#
# $$
# \min_x \ \phi(x) = \frac{1}{2} x^T H x + g^T x
# $$
#
# subject to
#
# $$
# A^T x = b
# $$
#
# where $H \succ 0$.
#
# ---

# %% [markdown]
# ### (a)
#  What is the Lagrangian function for this problem?

# %% [markdown]
# ---

# %% [markdown]
# ---
# ### (b)
# What are the first-order necessary optimality conditions for this problem?
# Are they also sufficient, and why?

# %% [markdown]
# ----

# %% [markdown]
# ---
#
# ### (c)
# 3. Make code for a test problem that is size dependent. Let $x \in \mathbb{R}^n$,
#    $A \in \mathbb{R}^{n \times m}$ with 15% of the elements nonzero,
#    $A_{ij} \sim \mathcal{N}(0,1)$, and
#
# $$
# m = \text{round}(\beta n), \quad 0 < \beta < 1.
# $$
#
# Let
#
# $$
# H = M M^T + \alpha I
# $$
#
# where $M \in \mathbb{R}^{n \times n}$ has 15% nonzero elements with
# $M_{ij} \sim \mathcal{N}(0,1)$.
#
# Let
#
# $$
# g_i \sim \mathcal{U}([-1,1]), \quad b_i \sim \mathcal{U}([-1,1]).
# $$
#
# Make sure that you can generate both dense and sparse matrices.
# Use the interface: function [H,g,A,b] = RandomEQP(n,alpha,density,beta,flag)
#
# , where
# flag indicates whether the method returns dense or sparse matrices.

# %% [markdown]
# ---

# %%
import numpy as np
import time

import sys
import os

sys.path.append(os.path.abspath(".."))

from utils import SolutionStats

# %% [markdown]
# ---
#
# ### (d)

# %% [markdown]
# Implement solvers for the problem using:
#    - dense LDL factorization
#    - sparse LDL factorization
#
# Provide pseudo-code and source code. Use the interface: [x,lambda] = EqualityQPSolverXX(H,g,A,b)
# , where `XX` indicates the method.
#
# Also implement a wrapper: [x,lambda] = EqualityQPSolver(H,g,A,b,solver)
#
# , where solver is a flag used to switch between the different factorizations.

# %% [markdown]
# ---

# %% [markdown]
# ---
#
# ### (e)
# Test and compare your equality constrained QP solvers as function of the
# problem size n and number of constraints $m = \beta n$, 0 < $ \beta $ < 1. Plot
# the CPU time for your solvers as function of n for different values of β.
# Discuss your observations.

# %% [markdown]
# ---

# %% [markdown]
# ----
