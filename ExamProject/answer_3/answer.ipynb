# %% [markdown]
# ##  3 Linear Program (LP)
#
# Consider the linear program
#
# $$
# \min_x \ \phi(x) = g^T x
# $$
#
# subject to
#
# $$
# b_l \le A^T x \le b_u, \quad x_l \le x \le x_u
# $$
#
# Assume that $A$ has full column rank.

# %% [markdown]
# ---
#
#
# ### (a)
#
# What is the Lagrangian function for this problem?
#
# ---

# %% [markdown]
# ---
# ### (b)
#
# Write the necessary and sufficient optimality conditions.
#
# ---

# %% [markdown]
# ---
#
# ### (c)
#
# Generate code for creating test problems in the form (3). Describe
# the code.
#
# ---

# %%
import numpy as np
import time

import sys
import os

sys.path.append(os.path.abspath(".."))

from utils import SolutionStats

# %% [markdown]
# ---
#
# ### (d)
#
# Solve the test problems using Matlab’s linprog or/and other library
# LP solvers. Read linprog’s documentation to make sure you pass
# the input correctly. You are welcome to (also) solve the problem
# with other optimization software, e.g. IPOPT with Casadi, JuMP with
# Gurobi in Julia, etc. Document this by providing code in the report.
# Report solution statistics (number of iterations, CPU time, etc).
#
# ---

# %% [markdown]
# ---
#
# ### (e)
#
# Write pseudo-code for a primal-dual interior-point algorithm tailored
# for the solution of the problem (3). Explain each major step in your
# algorithm.
#
# ---

# %% [markdown]
# ---
#
# ### (f)
#
# Implement the primal-dual interior-point algorithm and test it on
# the test problems. The primal-dual interior-point algorithm should
# be tailored to the LP in the form (3). You must provide commented
# code as well as driver files to test your code, documentation that it
# works, and performance statistics. You should describe the code.
#
# ---

# %% [markdown]
# ---
#
# ### (g)
#
# Write pseudo-code for a primal active-set algorithm (a revised sim-
# plex algorithm) for the linear program (3). Explain each major step
# in the algorithm. You can either convert the problem to the standard
# LP (less efficient) and give and algorithm. You can also provide an
# algorithm tailored for the structure (3) (more efficient). You are also
# welcome to do both.
#
# ---

# %% [markdown]
# ---
#
# ### (h)
#
# Implement a primal active-set algorithm (a revised simplex algo-
# rithm) for the linear program (3) and test it. You must provide
# commented code as well as driver files to test your code, documenta-
# tion that it works, and performance statistics.
#
# ---

# %% [markdown]
# ---
#
# ### (i)
#
# Compare the library LP solvers, the active-set LP solver(s), and the
# primal-dual LP solver for the test problems. Discuss the performance
# of the solvers. Provide tables and figures to illustrate the performance
# of different solvers for your test problem.
#
# ---
