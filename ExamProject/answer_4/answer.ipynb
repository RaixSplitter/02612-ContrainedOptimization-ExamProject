# %% [markdown]
# ## 4 Nonlinear Program (NLP)
#
# Consider the nonlinear program
#
# $$
# \min_x \ f(x)
# $$
#
# subject to
#
# $$
# g_l \le g(x) \le g_u, \quad x_l \le x \le x_u
# $$
#
# Assume that the functions are sufficiently smooth and that $\nabla g(x)$ has full column rank.

# %% [markdown]
# ---
#
# ### (a)
# What is the Lagrangian function for the nonlinear program (4)?
#
# ---

# %% [markdown]
# ---
#
# ### (b)
# What is the necessary first order optimality conditions for the non-
# linear program (4)?
#
# ---

# %% [markdown]
# ---
#
# ### (c)
# What are the sufficient second order optimality conditions for the
# nonlinear program (4).
#
# ---

# %% [markdown]
# ---
#
# ### (d)
# Demonstrate and explain that the QP subproblem of (4) can be ex-
# pressed in the form (2). What is (H, g, A, bl , bu, xl , xu ) in the QP
# subproblem in terms of the functions in (4). Explain this in the SQP
# algorithm with a) the analytical 2nd order derivatives are available
# for functions, and b) the Quasi-Newton case with only gradients of
# the functions available.
#
# ---

# %% [markdown]
# ---
#
# ### (e)
# Consider Himmelblau’s test problem. Convert this problem into the
# form (4). Provide the contour plot of the problem and locate all
# stationary points.
#
# ---

# %%
import numpy as np
import time

import sys
import os

sys.path.append(os.path.abspath(".."))

from utils import SolutionStats

# %% [markdown]
# ---
#
# ### (f)
# Solve the test problem (Himmelblau) using a library function for
# nonlinear programs. This can be fmincon, ipopt or others.
#
# ---

# %% [markdown]
# ---
#
# ### (g)
# Explain (this includes providing an algorithm or a pseudo-algorithm),
# discuss and implement an SQP procedure based on line-search for
# the solution of the problem (4). For the Hessian of the objective
# function, your algorithm should be able to switch between using a
# user-provided analytical expression and the damped BFGS approxi-
# mation. Test the algorithm on the test problem. Discuss the results.
#
# ---

# %% [markdown]
# ---
#
# ### (h)
# Explain (this includes providing an algorithm or a pseudo-algorithm),
# discuss, and implement a Trust Region based SQP algorithm for the
# problem. Test the algorithm on the test problem. Discuss the results.
#
# ---

# %% [markdown]
# ---
#
# ### (i)
# Test your algorithms and library NLP solvers on other relevant prob-
# lem(s) of your choice. Present the problem(s) and the solution. Ex-
# plain how and why you choose your test problems. Report the com-
# putational results in tables and figures. Explain and discuss the
# computational results.
#
# ---
